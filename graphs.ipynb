# %%
import seaborn as sns
import pandas as pd

# %% [markdown]
# # Transformer

# %%
transformer_train_loss = [
  1.4082,
  1.0678,
  0.8916,
  0.7619,
  0.6622,
  0.5822,
  0.5212,
  0.4694,
  0.4314,
  0.4051,
  0.3769,
  0.3558,
  0.3387,
  0.3277,
  0.3135,
  0.3015,
  0.2916,
  0.2862,
  0.2805,
  0.2742,
]

transformer_val_loss = [
  1.1948,
  0.9688,
  0.8510,
  0.7311,
  0.6390,
  0.5759,
  0.5640,
  0.5053,
  0.4710,
  0.4391,
  0.4209,
  0.4400,
  0.3919,
  0.3850,
  0.3703,
  0.3618,
  0.3549,
  0.3565,
  0.3742,
  0.3564
]

# %%
epochs = list(range(20))
data = pd.DataFrame({
  'epoch': epochs,
  'Train': transformer_train_loss,
  'Validation': transformer_val_loss,
})

ax = sns.lineplot(x='epoch', y='value', hue='variable', data=pd.melt(data, ['epoch']))
ax.set_title("ViT Loss")
ax.set_ylabel("Loss")
# Out:
# Text(0, 0.5, 'Loss')

# %% [markdown]
# # CNN

# %%
cnn_train_loss = [
  1.1995,
  0.8465,
  0.7004,
  0.6061,
  0.5393,
  0.4834,
  0.4399,
  0.4071,
  0.3764,
  0.3487,
  0.3316,
  0.3103,
  0.2931,
  0.2854,
  0.2710,
  0.2629,
  0.2541,
  0.2455,
  0.2407,
  0.2342
]

cnn_val_loss = [
  0.9865,
  0.7768,
  0.6559,
  0.6008,
  0.5481,
  0.5134,
  0.4901,
  0.4352,
  0.4070,
  0.4220,
  0.3904,
  0.3726,
  0.3437,
  0.3387,
  0.3297,
  0.3220,
  0.3275,
  0.3159,
  0.3256,
  0.2979
]

# %%
epochs = list(range(20))
data = pd.DataFrame({
  'epoch': epochs,
  'Train': cnn_train_loss,
  'Validation': cnn_val_loss,
})

ax = sns.lineplot(x='epoch', y='value', hue='variable', data=pd.melt(data, ['epoch']))
ax.set_title("CNN Loss")
ax.set_ylabel("Loss")
# Out:
# Text(0, 0.5, 'Loss')
